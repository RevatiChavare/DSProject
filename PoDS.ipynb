# %% [markdown]
# # Assignment- Data Science

# %% [markdown]
# <b>Importing all required libraries....</b>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %config InlineBackend.figure_format='retina'
sns.set(
    rc={ "figure.figsize": (14,6) },
    style="ticks", context="notebook", font_scale=1.2
)

# %% [markdown]
# <b>Loading dataset....</b>

# %%
advert=pd.read_csv('adverts.csv')

# %%
advert.head(5)
# Out:
#    public_reference   mileage reg_code standard_colour standard_make  \
# 0   202006039777689       0.0      NaN            Grey         Volvo
# 1   202007020778260  108230.0       61            Blue        Jaguar
# 2   202007020778474    7800.0       17            Grey         SKODA
# 3   202007080986776   45000.0       16           Brown      Vauxhall
# 4   202007161321269   64000.0       64            Grey    Land Rover
#
#       standard_model vehicle_condition  year_of_registration  price  \
# 0               XC90               NEW                   NaN  73970
# 1                 XF              USED                2011.0   7000
# 2               Yeti              USED                2017.0  14000
# 3              Mokka              USED                2016.0   7995
# 4  Range Rover Sport              USED                2015.0  26995
#
#    body_type  crossover_car_and_van              fuel_type
# 0        SUV                  False  Petrol Plug-in Hybrid
# ...

# %%
advert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 402005 entries, 0 to 402004
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   public_reference       402005 non-null  int64
#  1   mileage                401878 non-null  float64
#  2   reg_code               370148 non-null  object
#  3   standard_colour        396627 non-null  object
#  4   standard_make          402005 non-null  object
#  5   standard_model         402005 non-null  object
#  6   vehicle_condition      402005 non-null  object
#  7   year_of_registration   368694 non-null  float64
#  8   price                  402005 non-null  int64
#  9   body_type              401168 non-null  object
#  10  crossover_car_and_van  402005 non-null  bool
#  11  fuel_type              401404 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(7)
# memory usage: 34.1+ MB

# %% [markdown]
# <b>Checking for Nan values...</b>

# %%
advert.isna()
# Out:
#         public_reference  mileage  reg_code  standard_colour  standard_make  \
# 0                  False    False      True            False          False
# 1                  False    False     False            False          False
# 2                  False    False     False            False          False
# 3                  False    False     False            False          False
# 4                  False    False     False            False          False
# ...                  ...      ...       ...              ...            ...
# 402000             False    False     False            False          False
# 402001             False    False     False            False          False
# 402002             False    False     False            False          False
# 402003             False    False     False            False          False
# 402004             False    False     False            False          False
#
# ...

# %% [markdown]
# <b>Replacing Nan with '0'....</b>

# %%
advert=advert.fillna(0)

# %% [markdown]
# <b>Taking sample of data....</b>

# %%
sample_advert= advert.iloc[:40000,:]

# %%
sample_advert.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   public_reference       40000 non-null  int64
#  1   mileage                40000 non-null  float64
#  2   reg_code               40000 non-null  object
#  3   standard_colour        40000 non-null  object
#  4   standard_make          40000 non-null  object
#  5   standard_model         40000 non-null  object
#  6   vehicle_condition      40000 non-null  object
#  7   year_of_registration   40000 non-null  float64
#  8   price                  40000 non-null  int64
#  9   body_type              40000 non-null  object
#  10  crossover_car_and_van  40000 non-null  bool
#  11  fuel_type              40000 non-null  object
# dtypes: bool(1), float64(2), int64(2), object(7)
# memory usage: 3.4+ MB

# %%
sample_advert['fuel_type'].value_counts(normalize=True).plot.bar()
# Out:
# <AxesSubplot:>

# %%
sample_advert['body_type'].value_counts(normalize=True).plot.bar()
# Out:
# <AxesSubplot:>

# %%
sample_advert.head()
# Out:
#    public_reference   mileage reg_code standard_colour standard_make  \
# 0   202006039777689       0.0        0            Grey         Volvo
# 1   202007020778260  108230.0       61            Blue        Jaguar
# 2   202007020778474    7800.0       17            Grey         SKODA
# 3   202007080986776   45000.0       16           Brown      Vauxhall
# 4   202007161321269   64000.0       64            Grey    Land Rover
#
#       standard_model vehicle_condition  year_of_registration  price  \
# 0               XC90               NEW                   0.0  73970
# 1                 XF              USED                2011.0   7000
# 2               Yeti              USED                2017.0  14000
# 3              Mokka              USED                2016.0   7995
# 4  Range Rover Sport              USED                2015.0  26995
#
#    body_type  crossover_car_and_van              fuel_type
# 0        SUV                  False  Petrol Plug-in Hybrid
# ...

# %% [markdown]
# <b> Subsetting main dataset.....</b>

# %%
sample_1=sample_advert.drop(columns=['reg_code','standard_colour','standard_make','standard_model','body_type'])

# %%
sample_1.head(1)
# Out:
#    public_reference  mileage vehicle_condition  year_of_registration  price  \
# 0   202006039777689      0.0               NEW                   0.0  73970
#
#    crossover_car_and_van              fuel_type
# 0                  False  Petrol Plug-in Hybrid

# %%
sample_2=sample_advert.drop(columns=['reg_code','standard_colour','crossover_car_and_van','year_of_registration','public_reference','mileage','standard_make','standard_model','vehicle_condition'])

# %%
sample_2.head()
# Out:
#    price  body_type              fuel_type
# 0  73970        SUV  Petrol Plug-in Hybrid
# 1   7000     Saloon                 Diesel
# 2  14000        SUV                 Petrol
# 3   7995  Hatchback                 Diesel
# 4  26995        SUV                 Diesel

# %%
sample_2.corr()
# Out:
#        price
# price    1.0

# %%
sample_2.value_counts(['body_type', 'price']).sort_index()
# Out:
# body_type   price
# 0           745       1
#             3250      1
#             3950      1
#             4400      1
#             5400      1
#                      ..
# Saloon      269990    1
#             495000    2
# Window Van  8650      1
#             9995      1
#             44995     1
# Length: 14646, dtype: int64

# %%
sample_3=sample_advert.drop(columns=['reg_code','standard_colour','crossover_car_and_van','body_type','public_reference','mileage','fuel_type','vehicle_condition'])

# %%
sample_3.head()
# Out:
#   standard_make     standard_model  year_of_registration  price
# 0         Volvo               XC90                   0.0  73970
# 1        Jaguar                 XF                2011.0   7000
# 2         SKODA               Yeti                2017.0  14000
# 3      Vauxhall              Mokka                2016.0   7995
# 4    Land Rover  Range Rover Sport                2015.0  26995

# %%
sample_3['year_of_registration']=sample_3['year_of_registration'].astype(int)

# %%
sample_3.query('year_of_registration > 2000')
# Out:
#       standard_make     standard_model  year_of_registration   price
# 1            Jaguar                 XF                  2011    7000
# 2             SKODA               Yeti                  2017   14000
# 3          Vauxhall              Mokka                  2016    7995
# 4        Land Rover  Range Rover Sport                  2015   26995
# 5              Audi                 S5                  2017   29000
# ...             ...                ...                   ...     ...
# 39994       Porsche                911                  2016  168500
# 39995      Vauxhall              Corsa                  2019    9247
# 39996           BMW           4 Series                  2014   14495
# 39997    Land Rover    Discovery Sport                  2020   40844
# 39999         SKODA             Citigo                  2013    4800
#
# [36443 rows x 4 columns]

# %%
sample_3.value_counts(['year_of_registration', 'price']).sort_index()
# Out:
# year_of_registration  price
# 0                     2250      1
#                       3500      1
#                       3950      1
#                       4345      1
#                       4950      1
#                                ..
# 2020                  324950    1
#                       348480    1
#                       419990    1
#                       439999    1
#                       674995    1
# Length: 18152, dtype: int64

# %%
sample_3['price'].min()
# Out:
# 250

# %%
sample_3['price'].max()
# Out:
# 1590000

# %%
sns.scatterplot(data=sample_3, x='year_of_registration',y='price',alpha=0.3)
plt.xlim(2000,2025)
plt.ylim(250,1590000)
#Considering year_of_registration from 2000 onwards.
#And price between min to max range mentioned in the dataset.
# Out:
# (250.0, 1590000.0)

# %%
sample_advert['vehicle_condition'].value_counts(normalize=True).plot.bar()
# Out:
# <AxesSubplot:>

# %% [markdown]
# <b>Converting categorical values to numeric</b>

# %%
#from sklearn import preprocessing

# %%
#le = preprocessing.LabelEncoder()

# %%
#y = pd.get_dummies(sample_1.vehicle_condition, prefix='vehicle_condition')
print(y.head())

# %%
#sample_1 = pd.concat([sample_1.drop(columns='vehicle_condition'),y], axis=1)
sample_1.head()

# %%
#z = pd.get_dummies(sample_1.fuel_type, prefix='fuel_type')
print(z.head())

# %%
#sample_1 = pd.concat([sample_1.drop(columns=['fuel_type']),z], axis=1)
sample_1.head()
# Out:
#    public_reference   mileage vehicle_condition  year_of_registration  price  \
# 0   202006039777689       0.0               NEW                   0.0  73970
# 1   202007020778260  108230.0              USED                2011.0   7000
# 2   202007020778474    7800.0              USED                2017.0  14000
# 3   202007080986776   45000.0              USED                2016.0   7995
# 4   202007161321269   64000.0              USED                2015.0  26995
#
#    crossover_car_and_van              fuel_type
# 0                  False  Petrol Plug-in Hybrid
# 1                  False                 Diesel
# 2                  False                 Petrol
# 3                  False                 Diesel
# 4                  False                 Diesel

# %%
sns.histplot(x=sample_advert['mileage'],y=sample_1['price']).set(ylim=(0,500000))
# Out:
# [(0.0, 500000.0)]

# %%
sample_5=sample_advert[['price','year_of_registration','body_type','fuel_type']]

# %%
sample_5=sample_5.query("year_of_registration>2000")

# %%
sample_5=sample_5.query("fuel_type !=0")

# %%
sample_5.head()
# Out:
#    price  year_of_registration    body_type fuel_type
# 1   7000                2011.0       Saloon    Diesel
# 2  14000                2017.0          SUV    Petrol
# 3   7995                2016.0    Hatchback    Diesel
# 4  26995                2015.0          SUV    Diesel
# 5  29000                2017.0  Convertible    Petrol

# %%
sns.lmplot(
    data=sample_5, x='year_of_registration', y='price',hue='fuel_type', col='body_type', col_wrap=3,
    scatter_kws=dict(alpha=0.1), height=4, lowess=True).set(ylim=(0,300000))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\statsmodels\nonparametric\smoothers_lowess.py:227: RuntimeWarning: invalid value encountered in true_divide
#   res, _ = _lowess(y, x, x, np.ones_like(x),

# %%
sns.catplot(
    data=sample_5, col='body_type', hue='fuel_type', x='year_of_registration', y='price', height=4, col_wrap=3
);

# %%
rnd = sample_advert.groupby(['body_type', 'vehicle_condition'])['price'].median().unstack()
rnd.head(10)
# Out:
# vehicle_condition      NEW     USED
# body_type
# 0                  26032.5  19990.0
# Camper                 NaN  12500.0
# Car Derived Van        NaN   3995.0
# Combi Van          31979.0  13147.5
# Convertible        36659.0  14599.0
# Coupe              51558.0  17994.0
# Estate             37708.0  12996.5
# Hatchback          18727.5   8590.0
# Limousine              NaN  10847.5
# MPV                28990.0   9745.0

# %%
plt.subplots(figsize=(8,6))
sns.heatmap(
    data=rnd, cmap='Blues'
);

# %%
sns.violinplot(data=sample_advert, x='price', y='year_of_registration');
# Out:
# Error in callback <function flush_figures at 0x000001DCBADC68B0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %%
sample_advert.groupby('body_type')['price'].mean()
# Out:
# body_type
# 0                  26345.012658
# Camper             12500.000000
# Car Derived Van     3995.000000
# Combi Van          17473.300000
# Convertible        27660.985093
# Coupe              34048.670513
# Estate             16489.131369
# Hatchback          10517.831545
# Limousine          55527.062500
# MPV                10921.149660
# Minibus            18212.294118
# Panel Van          27492.375000
# Pickup             17136.480769
# SUV                22480.353074
# Saloon             19039.407457
# Window Van         21213.333333
# Name: price, dtype: float64
